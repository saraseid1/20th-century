# %%
import spacy
nlp = spacy.load("en_core_web_sm")

with open("20th_century_events.txt", "r") as file:
    text = file.read()

doc = nlp(text)

[(ent.text, ent.label_) for ent in doc.ents[:20]]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/r7/hpnbv35s3194ffb_bhsw50nc0000gn/T/ipykernel_4788/2544664021.py in <module>
# ----> 1 import spacy
#       2 nlp = spacy.load("en_core_web_sm")
#       3
#       4 with open("20th_century_events.txt", "r") as file:
#       5     text = file.read()
#
# ModuleNotFoundError: No module named 'spacy'
